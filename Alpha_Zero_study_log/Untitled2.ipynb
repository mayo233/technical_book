# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
x = tf.placeholder(tf.float32, [None,1])
y_answer = tf.placeholder(tf.float32)
noise=0.05*np.random.rand(100).astype(np.float32) #ノイズを作成
theta=np.random.randint(0,360)

# %%
def init_weight_variable(shape):
    """Initialize variable in a suitable way for weights."""
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)


def init_bias_variable(shape):
    """Initialize variable in a suitable way for biases."""
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)


# Step 1. Prepare data
x_data = np.linspace(0., 2 * np.pi, 100)[:, None]
y_data = np.sin(x_data)+noise+theta


# Step 2. Define operation
#x = tf.placeholder(tf.float32, [None,1])
#y_answer = tf.placeholder(tf.float32)

n_var = 5

w1 = init_weight_variable((1, n_var))
b1 = init_bias_variable((n_var,))
h1 = tf.nn.relu(tf.matmul(x, w1) + b1)
y_mode
#w2 = init_weight_variable((n_var, n_var))
#b2 = init_bias_variable((n_var,))
#h2 = tf.nn.relu(tf.matmul(h1, w2) + b2)

w3 = init_weight_variable((n_var, 1))
b3 = init_bias_variable((1,))
y_model = tf.matmul(h2, w3) + b3

loss = tf.reduce_mean((y_model - y_answer)**2)
train = tf.train.AdamOptimizer().minimize(loss)

init = tf.global_variables_initializer()

# Step 3. Run operation
sess= tf.Session()
sess.run(init)
for i in range(10000):
    sess.run(train, {x: x_data, y_answer: y_data})
    if i % 1000 == 0:
        current_loss, current_y_model = sess.run([loss, y_model], {x: x_data, y_answer: y_data})
        print(f"Loss: {current_loss}")
current_loss, current_y_model = sess.run([loss, y_model], {x: x_data, y_answer: y_data})

fig,ax=plt.subplots(figsize=(8,4))
#plt.plot(x_data, y_data)
plt.plot(x_data, current_y_model)
#plt.legend()
#ax.scatter(x_data,y_data)  #観測データのプロット
#ax.scatter(x_data,current_y_model)  #観測データのプロット
fig.suptitle('result')  
plt.show()
sess.close() #tensorflowセッションを終了
