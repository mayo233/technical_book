# %%
#DQN. 深層学習とQ学習を組み合わせた手法  経験をたくさんメモリに貯めてあとでランダムに学習
#行動評価関数をNNで表現  
#パッケージのインポート
import gym
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from collections import deque
from tensorflow.compat.v1.losses import huber_loss

# %%
#パラメータの準備
NUM_EPISODES=500 #学習するエピソード数
MAX_STEPS=200 #最大ステップ数　1エピソード内の
GAMMA=0.99 #時間割引率 Q学習の
WARMUP=10 #無操作ステップ数 環境をリセットした際の無操作

#探索パラメータ
E_START=1.0 #εの初期値
E_STOP=0.01 #εの最終値
E_DECAY_RATE=0.001 #εの減衰率

#メモリパラメータ 
MEMORY_SIZE=10000 #経験メモリのサイズ
BATCH_SIZE=32 #バッチサイズ

# %%
#全結合層を４つ重ねたモdる
#行動評価関数の定義
class QNetwork:
  #初期化
  def __init__(self,state_size,action_size):
    #モデルの作成
    self.model=Sequential()
    self.model.add(Dense(16,activation='relu',input_dim=state_size))
    self.model.add(Dense(16,activation='relu'))
    self.model.add(Dense(16,activation='relu'))
    self.model.add(Dense(action_size,activation='linear'))

    #モデルのコンパイル
    self.model.compile(loss=huber_loss,optimizer=Adam(lr=0.001))

# %%
#経験メモリの定義　経験，状態，行動，報酬，次の状態
class Memory():
  #初期化
    def __init__(self,memory_size):
      self.buffer=deque(maxlen=memory_size)

    #経験の追加
    def add(self,experience):
      self.buffer.append(experience)

    #バッチサイズ分の経験をランダムに取得  NNの学習を行う
    def sample(self,batch_size):
      idx=np.random.choice(np.arange(len(self.buffer)),size=batch_size,replace=False)
      return [self.buffer[i] for i in idx]

    #経験メモリのサイズ
    def __len__(self):
      return len(self.buffer)

# %%
#環境の作成
env=gym.make('CartPole-v0')
state_size=env.observation_space.shape[0] #行動数
action_size=env.action_space.n #状態数

#main-networkの作成
main_qn=QNetwork(state_size,action_size)

#target-networkの作成
target_qn=QNetwork(state_size,action_size)

#経験メモリの作成
memory=Memory(MEMORY_SIZE)

# %%
#学習の開始　環境のリセット　エピソードの反復 
#環境の初期化
state=env.reset()
state=np.reshape(state,[1,state_size])

#エピソード数分のエピソードを繰り返す
total_step=0 #総ステップ数
success_count=0 #成功数
for episode in range(1,NUM_EPISODES+1):
  step=0 #ステップ数

  #target-networkの更新
  target_qn.model.set_weights(main_qn.model.get_weights())

  #1エピソードのループ

  #エピソード完了時のログ表示
  print('エピソード:{}, ステップ数:{},epsilon:{:.4f}'.format(episode,step,epsilon))

  #５回連続成功で学習終了
  if success_count>=5:
    break

  #環境のリセット
  state=env.reset()
  state=np.reshape(state,[1,state_size])
# Out:
# エピソード:1, ステップ数:0,epsilon:0.8205
# エピソード:2, ステップ数:0,epsilon:0.8205
# エピソード:3, ステップ数:0,epsilon:0.8205
# エピソード:4, ステップ数:0,epsilon:0.8205
# エピソード:5, ステップ数:0,epsilon:0.8205
# エピソード:6, ステップ数:0,epsilon:0.8205
# エピソード:7, ステップ数:0,epsilon:0.8205
# エピソード:8, ステップ数:0,epsilon:0.8205
# エピソード:9, ステップ数:0,epsilon:0.8205
# エピソード:10, ステップ数:0,epsilon:0.8205
# エピソード:11, ステップ数:0,epsilon:0.8205
# エピソード:12, ステップ数:0,epsilon:0.8205
# エピソード:13, ステップ数:0,epsilon:0.8205
# エピソード:14, ステップ数:0,epsilon:0.8205
# エピソード:15, ステップ数:0,epsilon:0.8205
# エピソード:16, ステップ数:0,epsilon:0.8205
# エピソード:17, ステップ数:0,epsilon:0.8205
# エピソード:18, ステップ数:0,epsilon:0.8205
# エピソード:19, ステップ数:0,epsilon:0.8205
# エピソード:20, ステップ数:0,epsilon:0.8205
# エピソード:21, ステップ数:0,epsilon:0.8205
# エピソード:22, ステップ数:0,epsilon:0.8205
# エピソード:23, ステップ数:0,epsilon:0.8205
# エピソード:24, ステップ数:0,epsilon:0.8205
# エピソード:25, ステップ数:0,epsilon:0.8205
# エピソード:26, ステップ数:0,epsilon:0.8205
# エピソード:27, ステップ数:0,epsilon:0.8205
# エピソード:28, ステップ数:0,epsilon:0.8205
# エピソード:29, ステップ数:0,epsilon:0.8205
# エピソード:30, ステップ数:0,epsilon:0.8205
# エピソード:31, ステップ数:0,epsilon:0.8205
# エピソード:32, ステップ数:0,epsilon:0.8205
# エピソード:33, ステップ数:0,epsilon:0.8205
# エピソード:34, ステップ数:0,epsilon:0.8205
# エピソード:35, ステップ数:0,epsilon:0.8205
# エピソード:36, ステップ数:0,epsilon:0.8205
# エピソード:37, ステップ数:0,epsilon:0.8205
# エピソード:38, ステップ数:0,epsilon:0.8205
# エピソード:39, ステップ数:0,epsilon:0.8205
# エピソード:40, ステップ数:0,epsilon:0.8205
# エピソード:41, ステップ数:0,epsilon:0.8205
# エピソード:42, ステップ数:0,epsilon:0.8205
# エピソード:43, ステップ数:0,epsilon:0.8205
# エピソード:44, ステップ数:0,epsilon:0.8205
# エピソード:45, ステップ数:0,epsilon:0.8205
# エピソード:46, ステップ数:0,epsilon:0.8205
# エピソード:47, ステップ数:0,epsilon:0.8205
# エピソード:48, ステップ数:0,epsilon:0.8205
# エピソード:49, ステップ数:0,epsilon:0.8205
# エピソード:50, ステップ数:0,epsilon:0.8205
# エピソード:51, ステップ数:0,epsilon:0.8205
# エピソード:52, ステップ数:0,epsilon:0.8205
# エピソード:53, ステップ数:0,epsilon:0.8205
# エピソード:54, ステップ数:0,epsilon:0.8205
# エピソード:55, ステップ数:0,epsilon:0.8205
# エピソード:56, ステップ数:0,epsilon:0.8205
# エピソード:57, ステップ数:0,epsilon:0.8205
# エピソード:58, ステップ数:0,epsilon:0.8205
# エピソード:59, ステップ数:0,epsilon:0.8205
# エピソード:60, ステップ数:0,epsilon:0.8205
# エピソード:61, ステップ数:0,epsilon:0.8205
# エピソード:62, ステップ数:0,epsilon:0.8205
# エピソード:63, ステップ数:0,epsilon:0.8205
# エピソード:64, ステップ数:0,epsilon:0.8205
# エピソード:65, ステップ数:0,epsilon:0.8205
# エピソード:66, ステップ数:0,epsilon:0.8205
# エピソード:67, ステップ数:0,epsilon:0.8205
# エピソード:68, ステップ数:0,epsilon:0.8205
# エピソード:69, ステップ数:0,epsilon:0.8205
# エピソード:70, ステップ数:0,epsilon:0.8205
# エピソード:71, ステップ数:0,epsilon:0.8205
# エピソード:72, ステップ数:0,epsilon:0.8205
# エピソード:73, ステップ数:0,epsilon:0.8205
# エピソード:74, ステップ数:0,epsilon:0.8205
# エピソード:75, ステップ数:0,epsilon:0.8205
# エピソード:76, ステップ数:0,epsilon:0.8205
# エピソード:77, ステップ数:0,epsilon:0.8205
# エピソード:78, ステップ数:0,epsilon:0.8205
# エピソード:79, ステップ数:0,epsilon:0.8205
# エピソード:80, ステップ数:0,epsilon:0.8205
# エピソード:81, ステップ数:0,epsilon:0.8205
# エピソード:82, ステップ数:0,epsilon:0.8205
# エピソード:83, ステップ数:0,epsilon:0.8205
# エピソード:84, ステップ数:0,epsilon:0.8205
# エピソード:85, ステップ数:0,epsilon:0.8205
# エピソード:86, ステップ数:0,epsilon:0.8205
# エピソード:87, ステップ数:0,epsilon:0.8205
# エピソード:88, ステップ数:0,epsilon:0.8205
# エピソード:89, ステップ数:0,epsilon:0.8205
# エピソード:90, ステップ数:0,epsilon:0.8205
# エピソード:91, ステップ数:0,epsilon:0.8205
# エピソード:92, ステップ数:0,epsilon:0.8205
# エピソード:93, ステップ数:0,epsilon:0.8205
# エピソード:94, ステップ数:0,epsilon:0.8205
# エピソード:95, ステップ数:0,epsilon:0.8205
# エピソード:96, ステップ数:0,epsilon:0.8205
# エピソード:97, ステップ数:0,epsilon:0.8205
# エピソード:98, ステップ数:0,epsilon:0.8205
# エピソード:99, ステップ数:0,epsilon:0.8205
# エピソード:100, ステップ数:0,epsilon:0.8205
# エピソード:101, ステップ数:0,epsilon:0.8205
# エピソード:102, ステップ数:0,epsilon:0.8205
# エピソード:103, ステップ数:0,epsilon:0.8205
# エピソード:104, ステップ数:0,epsilon:0.8205
# エピソード:105, ステップ数:0,epsilon:0.8205
# エピソード:106, ステップ数:0,epsilon:0.8205
# エピソード:107, ステップ数:0,epsilon:0.8205
# エピソード:108, ステップ数:0,epsilon:0.8205
# エピソード:109, ステップ数:0,epsilon:0.8205
# エピソード:110, ステップ数:0,epsilon:0.8205
# エピソード:111, ステップ数:0,epsilon:0.8205
# エピソード:112, ステップ数:0,epsilon:0.8205
# エピソード:113, ステップ数:0,epsilon:0.8205
# エピソード:114, ステップ数:0,epsilon:0.8205
# エピソード:115, ステップ数:0,epsilon:0.8205
# エピソード:116, ステップ数:0,epsilon:0.8205
# エピソード:117, ステップ数:0,epsilon:0.8205
# エピソード:118, ステップ数:0,epsilon:0.8205
# エピソード:119, ステップ数:0,epsilon:0.8205
# エピソード:120, ステップ数:0,epsilon:0.8205
# エピソード:121, ステップ数:0,epsilon:0.8205
# エピソード:122, ステップ数:0,epsilon:0.8205
# エピソード:123, ステップ数:0,epsilon:0.8205
# エピソード:124, ステップ数:0,epsilon:0.8205
# エピソード:125, ステップ数:0,epsilon:0.8205
# エピソード:126, ステップ数:0,epsilon:0.8205
# エピソード:127, ステップ数:0,epsilon:0.8205
# エピソード:128, ステップ数:0,epsilon:0.8205
# エピソード:129, ステップ数:0,epsilon:0.8205
# エピソード:130, ステップ数:0,epsilon:0.8205
# エピソード:131, ステップ数:0,epsilon:0.8205
# エピソード:132, ステップ数:0,epsilon:0.8205
# エピソード:133, ステップ数:0,epsilon:0.8205
# エピソード:134, ステップ数:0,epsilon:0.8205
# エピソード:135, ステップ数:0,epsilon:0.8205
# エピソード:136, ステップ数:0,epsilon:0.8205
# エピソード:137, ステップ数:0,epsilon:0.8205
# エピソード:138, ステップ数:0,epsilon:0.8205
# エピソード:139, ステップ数:0,epsilon:0.8205
# エピソード:140, ステップ数:0,epsilon:0.8205
# エピソード:141, ステップ数:0,epsilon:0.8205
# エピソード:142, ステップ数:0,epsilon:0.8205
# エピソード:143, ステップ数:0,epsilon:0.8205
# エピソード:144, ステップ数:0,epsilon:0.8205
# エピソード:145, ステップ数:0,epsilon:0.8205
# エピソード:146, ステップ数:0,epsilon:0.8205
# エピソード:147, ステップ数:0,epsilon:0.8205
# エピソード:148, ステップ数:0,epsilon:0.8205
# エピソード:149, ステップ数:0,epsilon:0.8205
# エピソード:150, ステップ数:0,epsilon:0.8205
# エピソード:151, ステップ数:0,epsilon:0.8205
# エピソード:152, ステップ数:0,epsilon:0.8205
# エピソード:153, ステップ数:0,epsilon:0.8205
# エピソード:154, ステップ数:0,epsilon:0.8205
# エピソード:155, ステップ数:0,epsilon:0.8205
# エピソード:156, ステップ数:0,epsilon:0.8205
# エピソード:157, ステップ数:0,epsilon:0.8205
# エピソード:158, ステップ数:0,epsilon:0.8205
# エピソード:159, ステップ数:0,epsilon:0.8205
# エピソード:160, ステップ数:0,epsilon:0.8205
# エピソード:161, ステップ数:0,epsilon:0.8205
# エピソード:162, ステップ数:0,epsilon:0.8205
# エピソード:163, ステップ数:0,epsilon:0.8205
# エピソード:164, ステップ数:0,epsilon:0.8205
# エピソード:165, ステップ数:0,epsilon:0.8205
# エピソード:166, ステップ数:0,epsilon:0.8205
# エピソード:167, ステップ数:0,epsilon:0.8205
# エピソード:168, ステップ数:0,epsilon:0.8205
# エピソード:169, ステップ数:0,epsilon:0.8205
# エピソード:170, ステップ数:0,epsilon:0.8205
# エピソード:171, ステップ数:0,epsilon:0.8205
# エピソード:172, ステップ数:0,epsilon:0.8205
# エピソード:173, ステップ数:0,epsilon:0.8205
# エピソード:174, ステップ数:0,epsilon:0.8205
# エピソード:175, ステップ数:0,epsilon:0.8205
# エピソード:176, ステップ数:0,epsilon:0.8205
# エピソード:177, ステップ数:0,epsilon:0.8205
# エピソード:178, ステップ数:0,epsilon:0.8205
# エピソード:179, ステップ数:0,epsilon:0.8205
# エピソード:180, ステップ数:0,epsilon:0.8205
# エピソード:181, ステップ数:0,epsilon:0.8205
# エピソード:182, ステップ数:0,epsilon:0.8205
# エピソード:183, ステップ数:0,epsilon:0.8205
# エピソード:184, ステップ数:0,epsilon:0.8205
# エピソード:185, ステップ数:0,epsilon:0.8205
# エピソード:186, ステップ数:0,epsilon:0.8205
# エピソード:187, ステップ数:0,epsilon:0.8205
# エピソード:188, ステップ数:0,epsilon:0.8205
# エピソード:189, ステップ数:0,epsilon:0.8205
# エピソード:190, ステップ数:0,epsilon:0.8205
# エピソード:191, ステップ数:0,epsilon:0.8205
# エピソード:192, ステップ数:0,epsilon:0.8205
# エピソード:193, ステップ数:0,epsilon:0.8205
# エピソード:194, ステップ数:0,epsilon:0.8205
# エピソード:195, ステップ数:0,epsilon:0.8205
# エピソード:196, ステップ数:0,epsilon:0.8205
# エピソード:197, ステップ数:0,epsilon:0.8205
# エピソード:198, ステップ数:0,epsilon:0.8205
# エピソード:199, ステップ数:0,epsilon:0.8205
# エピソード:200, ステップ数:0,epsilon:0.8205
# エピソード:201, ステップ数:0,epsilon:0.8205
# エピソード:202, ステップ数:0,epsilon:0.8205
# エピソード:203, ステップ数:0,epsilon:0.8205
# エピソード:204, ステップ数:0,epsilon:0.8205
# エピソード:205, ステップ数:0,epsilon:0.8205
# エピソード:206, ステップ数:0,epsilon:0.8205
# エピソード:207, ステップ数:0,epsilon:0.8205
# エピソード:208, ステップ数:0,epsilon:0.8205
# エピソード:209, ステップ数:0,epsilon:0.8205
# エピソード:210, ステップ数:0,epsilon:0.8205
# エピソード:211, ステップ数:0,epsilon:0.8205
# エピソード:212, ステップ数:0,epsilon:0.8205
# エピソード:213, ステップ数:0,epsilon:0.8205
# エピソード:214, ステップ数:0,epsilon:0.8205
# エピソード:215, ステップ数:0,epsilon:0.8205
# エピソード:216, ステップ数:0,epsilon:0.8205
# エピソード:217, ステップ数:0,epsilon:0.8205
# エピソード:218, ステップ数:0,epsilon:0.8205
# エピソード:219, ステップ数:0,epsilon:0.8205
# エピソード:220, ステップ数:0,epsilon:0.8205
# エピソード:221, ステップ数:0,epsilon:0.8205
# エピソード:222, ステップ数:0,epsilon:0.8205
# エピソード:223, ステップ数:0,epsilon:0.8205
# エピソード:224, ステップ数:0,epsilon:0.8205
# エピソード:225, ステップ数:0,epsilon:0.8205
# エピソード:226, ステップ数:0,epsilon:0.8205
# エピソード:227, ステップ数:0,epsilon:0.8205
# エピソード:228, ステップ数:0,epsilon:0.8205
# エピソード:229, ステップ数:0,epsilon:0.8205
# エピソード:230, ステップ数:0,epsilon:0.8205
# エピソード:231, ステップ数:0,epsilon:0.8205
# エピソード:232, ステップ数:0,epsilon:0.8205
# エピソード:233, ステップ数:0,epsilon:0.8205
# エピソード:234, ステップ数:0,epsilon:0.8205
# エピソード:235, ステップ数:0,epsilon:0.8205
# エピソード:236, ステップ数:0,epsilon:0.8205
# エピソード:237, ステップ数:0,epsilon:0.8205
# エピソード:238, ステップ数:0,epsilon:0.8205
# エピソード:239, ステップ数:0,epsilon:0.8205
# エピソード:240, ステップ数:0,epsilon:0.8205
# エピソード:241, ステップ数:0,epsilon:0.8205
# エピソード:242, ステップ数:0,epsilon:0.8205
# エピソード:243, ステップ数:0,epsilon:0.8205
# エピソード:244, ステップ数:0,epsilon:0.8205
# エピソード:245, ステップ数:0,epsilon:0.8205
# エピソード:246, ステップ数:0,epsilon:0.8205
# エピソード:247, ステップ数:0,epsilon:0.8205
# エピソード:248, ステップ数:0,epsilon:0.8205
# エピソード:249, ステップ数:0,epsilon:0.8205
# エピソード:250, ステップ数:0,epsilon:0.8205
# エピソード:251, ステップ数:0,epsilon:0.8205
# エピソード:252, ステップ数:0,epsilon:0.8205
# エピソード:253, ステップ数:0,epsilon:0.8205
# エピソード:254, ステップ数:0,epsilon:0.8205
# エピソード:255, ステップ数:0,epsilon:0.8205
# エピソード:256, ステップ数:0,epsilon:0.8205
# エピソード:257, ステップ数:0,epsilon:0.8205
# エピソード:258, ステップ数:0,epsilon:0.8205
# エピソード:259, ステップ数:0,epsilon:0.8205
# エピソード:260, ステップ数:0,epsilon:0.8205
# エピソード:261, ステップ数:0,epsilon:0.8205
# エピソード:262, ステップ数:0,epsilon:0.8205
# エピソード:263, ステップ数:0,epsilon:0.8205
# エピソード:264, ステップ数:0,epsilon:0.8205
# エピソード:265, ステップ数:0,epsilon:0.8205
# エピソード:266, ステップ数:0,epsilon:0.8205
# エピソード:267, ステップ数:0,epsilon:0.8205
# エピソード:268, ステップ数:0,epsilon:0.8205
# エピソード:269, ステップ数:0,epsilon:0.8205
# エピソード:270, ステップ数:0,epsilon:0.8205
# エピソード:271, ステップ数:0,epsilon:0.8205
# エピソード:272, ステップ数:0,epsilon:0.8205
# エピソード:273, ステップ数:0,epsilon:0.8205
# エピソード:274, ステップ数:0,epsilon:0.8205
# エピソード:275, ステップ数:0,epsilon:0.8205
# エピソード:276, ステップ数:0,epsilon:0.8205
# エピソード:277, ステップ数:0,epsilon:0.8205
# エピソード:278, ステップ数:0,epsilon:0.8205
# エピソード:279, ステップ数:0,epsilon:0.8205
# エピソード:280, ステップ数:0,epsilon:0.8205
# エピソード:281, ステップ数:0,epsilon:0.8205
# エピソード:282, ステップ数:0,epsilon:0.8205
# エピソード:283, ステップ数:0,epsilon:0.8205
# エピソード:284, ステップ数:0,epsilon:0.8205
# エピソード:285, ステップ数:0,epsilon:0.8205
# エピソード:286, ステップ数:0,epsilon:0.8205
# エピソード:287, ステップ数:0,epsilon:0.8205
# エピソード:288, ステップ数:0,epsilon:0.8205
# エピソード:289, ステップ数:0,epsilon:0.8205
# エピソード:290, ステップ数:0,epsilon:0.8205
# エピソード:291, ステップ数:0,epsilon:0.8205
# エピソード:292, ステップ数:0,epsilon:0.8205
# エピソード:293, ステップ数:0,epsilon:0.8205
# エピソード:294, ステップ数:0,epsilon:0.8205
# エピソード:295, ステップ数:0,epsilon:0.8205
# エピソード:296, ステップ数:0,epsilon:0.8205
# エピソード:297, ステップ数:0,epsilon:0.8205
# エピソード:298, ステップ数:0,epsilon:0.8205
# エピソード:299, ステップ数:0,epsilon:0.8205
# エピソード:300, ステップ数:0,epsilon:0.8205
# エピソード:301, ステップ数:0,epsilon:0.8205
# エピソード:302, ステップ数:0,epsilon:0.8205
# エピソード:303, ステップ数:0,epsilon:0.8205
# エピソード:304, ステップ数:0,epsilon:0.8205
# エピソード:305, ステップ数:0,epsilon:0.8205
# エピソード:306, ステップ数:0,epsilon:0.8205
# エピソード:307, ステップ数:0,epsilon:0.8205
# エピソード:308, ステップ数:0,epsilon:0.8205
# エピソード:309, ステップ数:0,epsilon:0.8205
# エピソード:310, ステップ数:0,epsilon:0.8205
# エピソード:311, ステップ数:0,epsilon:0.8205
# エピソード:312, ステップ数:0,epsilon:0.8205
# エピソード:313, ステップ数:0,epsilon:0.8205
# エピソード:314, ステップ数:0,epsilon:0.8205
# エピソード:315, ステップ数:0,epsilon:0.8205
# エピソード:316, ステップ数:0,epsilon:0.8205
# エピソード:317, ステップ数:0,epsilon:0.8205
# エピソード:318, ステップ数:0,epsilon:0.8205
# エピソード:319, ステップ数:0,epsilon:0.8205
# エピソード:320, ステップ数:0,epsilon:0.8205
# エピソード:321, ステップ数:0,epsilon:0.8205
# エピソード:322, ステップ数:0,epsilon:0.8205
# エピソード:323, ステップ数:0,epsilon:0.8205
# エピソード:324, ステップ数:0,epsilon:0.8205
# エピソード:325, ステップ数:0,epsilon:0.8205
# エピソード:326, ステップ数:0,epsilon:0.8205
# エピソード:327, ステップ数:0,epsilon:0.8205
# エピソード:328, ステップ数:0,epsilon:0.8205
# エピソード:329, ステップ数:0,epsilon:0.8205
# エピソード:330, ステップ数:0,epsilon:0.8205
# エピソード:331, ステップ数:0,epsilon:0.8205
# エピソード:332, ステップ数:0,epsilon:0.8205
# エピソード:333, ステップ数:0,epsilon:0.8205
# エピソード:334, ステップ数:0,epsilon:0.8205
# エピソード:335, ステップ数:0,epsilon:0.8205
# エピソード:336, ステップ数:0,epsilon:0.8205
# エピソード:337, ステップ数:0,epsilon:0.8205
# エピソード:338, ステップ数:0,epsilon:0.8205
# エピソード:339, ステップ数:0,epsilon:0.8205
# エピソード:340, ステップ数:0,epsilon:0.8205
# エピソード:341, ステップ数:0,epsilon:0.8205
# エピソード:342, ステップ数:0,epsilon:0.8205
# エピソード:343, ステップ数:0,epsilon:0.8205
# エピソード:344, ステップ数:0,epsilon:0.8205
# エピソード:345, ステップ数:0,epsilon:0.8205
# エピソード:346, ステップ数:0,epsilon:0.8205
# エピソード:347, ステップ数:0,epsilon:0.8205
# エピソード:348, ステップ数:0,epsilon:0.8205
# エピソード:349, ステップ数:0,epsilon:0.8205
# エピソード:350, ステップ数:0,epsilon:0.8205
# エピソード:351, ステップ数:0,epsilon:0.8205
# エピソード:352, ステップ数:0,epsilon:0.8205
# エピソード:353, ステップ数:0,epsilon:0.8205
# エピソード:354, ステップ数:0,epsilon:0.8205
# エピソード:355, ステップ数:0,epsilon:0.8205
# エピソード:356, ステップ数:0,epsilon:0.8205
# エピソード:357, ステップ数:0,epsilon:0.8205
# エピソード:358, ステップ数:0,epsilon:0.8205
# エピソード:359, ステップ数:0,epsilon:0.8205
# エピソード:360, ステップ数:0,epsilon:0.8205
# エピソード:361, ステップ数:0,epsilon:0.8205
# エピソード:362, ステップ数:0,epsilon:0.8205
# エピソード:363, ステップ数:0,epsilon:0.8205
# エピソード:364, ステップ数:0,epsilon:0.8205
# エピソード:365, ステップ数:0,epsilon:0.8205
# エピソード:366, ステップ数:0,epsilon:0.8205
# エピソード:367, ステップ数:0,epsilon:0.8205
# エピソード:368, ステップ数:0,epsilon:0.8205
# エピソード:369, ステップ数:0,epsilon:0.8205
# エピソード:370, ステップ数:0,epsilon:0.8205
# エピソード:371, ステップ数:0,epsilon:0.8205
# エピソード:372, ステップ数:0,epsilon:0.8205
# エピソード:373, ステップ数:0,epsilon:0.8205
# エピソード:374, ステップ数:0,epsilon:0.8205
# エピソード:375, ステップ数:0,epsilon:0.8205
# エピソード:376, ステップ数:0,epsilon:0.8205
# エピソード:377, ステップ数:0,epsilon:0.8205
# エピソード:378, ステップ数:0,epsilon:0.8205
# エピソード:379, ステップ数:0,epsilon:0.8205
# エピソード:380, ステップ数:0,epsilon:0.8205
# エピソード:381, ステップ数:0,epsilon:0.8205
# エピソード:382, ステップ数:0,epsilon:0.8205
# エピソード:383, ステップ数:0,epsilon:0.8205
# エピソード:384, ステップ数:0,epsilon:0.8205
# エピソード:385, ステップ数:0,epsilon:0.8205
# エピソード:386, ステップ数:0,epsilon:0.8205
# エピソード:387, ステップ数:0,epsilon:0.8205
# エピソード:388, ステップ数:0,epsilon:0.8205
# エピソード:389, ステップ数:0,epsilon:0.8205
# エピソード:390, ステップ数:0,epsilon:0.8205
# エピソード:391, ステップ数:0,epsilon:0.8205
# エピソード:392, ステップ数:0,epsilon:0.8205
# エピソード:393, ステップ数:0,epsilon:0.8205
# エピソード:394, ステップ数:0,epsilon:0.8205
# エピソード:395, ステップ数:0,epsilon:0.8205
# エピソード:396, ステップ数:0,epsilon:0.8205
# エピソード:397, ステップ数:0,epsilon:0.8205
# エピソード:398, ステップ数:0,epsilon:0.8205
# エピソード:399, ステップ数:0,epsilon:0.8205
# エピソード:400, ステップ数:0,epsilon:0.8205
# エピソード:401, ステップ数:0,epsilon:0.8205
# エピソード:402, ステップ数:0,epsilon:0.8205
# エピソード:403, ステップ数:0,epsilon:0.8205
# エピソード:404, ステップ数:0,epsilon:0.8205
# エピソード:405, ステップ数:0,epsilon:0.8205
# エピソード:406, ステップ数:0,epsilon:0.8205
# エピソード:407, ステップ数:0,epsilon:0.8205
# エピソード:408, ステップ数:0,epsilon:0.8205
# エピソード:409, ステップ数:0,epsilon:0.8205
# エピソード:410, ステップ数:0,epsilon:0.8205
# エピソード:411, ステップ数:0,epsilon:0.8205
# エピソード:412, ステップ数:0,epsilon:0.8205
# エピソード:413, ステップ数:0,epsilon:0.8205
# エピソード:414, ステップ数:0,epsilon:0.8205
# エピソード:415, ステップ数:0,epsilon:0.8205
# エピソード:416, ステップ数:0,epsilon:0.8205
# エピソード:417, ステップ数:0,epsilon:0.8205
# エピソード:418, ステップ数:0,epsilon:0.8205
# エピソード:419, ステップ数:0,epsilon:0.8205
# エピソード:420, ステップ数:0,epsilon:0.8205
# エピソード:421, ステップ数:0,epsilon:0.8205
# エピソード:422, ステップ数:0,epsilon:0.8205
# エピソード:423, ステップ数:0,epsilon:0.8205
# エピソード:424, ステップ数:0,epsilon:0.8205
# エピソード:425, ステップ数:0,epsilon:0.8205
# エピソード:426, ステップ数:0,epsilon:0.8205
# エピソード:427, ステップ数:0,epsilon:0.8205
# エピソード:428, ステップ数:0,epsilon:0.8205
# エピソード:429, ステップ数:0,epsilon:0.8205
# エピソード:430, ステップ数:0,epsilon:0.8205
# エピソード:431, ステップ数:0,epsilon:0.8205
# エピソード:432, ステップ数:0,epsilon:0.8205
# エピソード:433, ステップ数:0,epsilon:0.8205
# エピソード:434, ステップ数:0,epsilon:0.8205
# エピソード:435, ステップ数:0,epsilon:0.8205
# エピソード:436, ステップ数:0,epsilon:0.8205
# エピソード:437, ステップ数:0,epsilon:0.8205
# エピソード:438, ステップ数:0,epsilon:0.8205
# エピソード:439, ステップ数:0,epsilon:0.8205
# エピソード:440, ステップ数:0,epsilon:0.8205
# エピソード:441, ステップ数:0,epsilon:0.8205
# エピソード:442, ステップ数:0,epsilon:0.8205
# エピソード:443, ステップ数:0,epsilon:0.8205
# エピソード:444, ステップ数:0,epsilon:0.8205
# エピソード:445, ステップ数:0,epsilon:0.8205
# エピソード:446, ステップ数:0,epsilon:0.8205
# エピソード:447, ステップ数:0,epsilon:0.8205
# エピソード:448, ステップ数:0,epsilon:0.8205
# エピソード:449, ステップ数:0,epsilon:0.8205
# エピソード:450, ステップ数:0,epsilon:0.8205
# エピソード:451, ステップ数:0,epsilon:0.8205
# エピソード:452, ステップ数:0,epsilon:0.8205
# エピソード:453, ステップ数:0,epsilon:0.8205
# エピソード:454, ステップ数:0,epsilon:0.8205
# エピソード:455, ステップ数:0,epsilon:0.8205
# エピソード:456, ステップ数:0,epsilon:0.8205
# エピソード:457, ステップ数:0,epsilon:0.8205
# エピソード:458, ステップ数:0,epsilon:0.8205
# エピソード:459, ステップ数:0,epsilon:0.8205
# エピソード:460, ステップ数:0,epsilon:0.8205
# エピソード:461, ステップ数:0,epsilon:0.8205
# エピソード:462, ステップ数:0,epsilon:0.8205
# エピソード:463, ステップ数:0,epsilon:0.8205
# エピソード:464, ステップ数:0,epsilon:0.8205
# エピソード:465, ステップ数:0,epsilon:0.8205
# エピソード:466, ステップ数:0,epsilon:0.8205
# エピソード:467, ステップ数:0,epsilon:0.8205
# エピソード:468, ステップ数:0,epsilon:0.8205
# エピソード:469, ステップ数:0,epsilon:0.8205
# エピソード:470, ステップ数:0,epsilon:0.8205
# エピソード:471, ステップ数:0,epsilon:0.8205
# エピソード:472, ステップ数:0,epsilon:0.8205
# エピソード:473, ステップ数:0,epsilon:0.8205
# エピソード:474, ステップ数:0,epsilon:0.8205
# エピソード:475, ステップ数:0,epsilon:0.8205
# エピソード:476, ステップ数:0,epsilon:0.8205
# エピソード:477, ステップ数:0,epsilon:0.8205
# エピソード:478, ステップ数:0,epsilon:0.8205
# エピソード:479, ステップ数:0,epsilon:0.8205
# エピソード:480, ステップ数:0,epsilon:0.8205
# エピソード:481, ステップ数:0,epsilon:0.8205
# エピソード:482, ステップ数:0,epsilon:0.8205
# エピソード:483, ステップ数:0,epsilon:0.8205
# エピソード:484, ステップ数:0,epsilon:0.8205
# エピソード:485, ステップ数:0,epsilon:0.8205
# エピソード:486, ステップ数:0,epsilon:0.8205
# エピソード:487, ステップ数:0,epsilon:0.8205
# エピソード:488, ステップ数:0,epsilon:0.8205
# エピソード:489, ステップ数:0,epsilon:0.8205
# エピソード:490, ステップ数:0,epsilon:0.8205
# エピソード:491, ステップ数:0,epsilon:0.8205
# エピソード:492, ステップ数:0,epsilon:0.8205
# エピソード:493, ステップ数:0,epsilon:0.8205
# エピソード:494, ステップ数:0,epsilon:0.8205
# エピソード:495, ステップ数:0,epsilon:0.8205
# エピソード:496, ステップ数:0,epsilon:0.8205
# エピソード:497, ステップ数:0,epsilon:0.8205
# エピソード:498, ステップ数:0,epsilon:0.8205
# エピソード:499, ステップ数:0,epsilon:0.8205
# エピソード:500, ステップ数:0,epsilon:0.8205

# %%
#1エピソードのループ
for _ in range(1,MAX_STEPS+1):
  step+=1
  total_step+=1

  #εを減らす
  epsilon=E_STOP+(E_START-E_STOP)*np.exp(-E_DECAY_RATE*total_step)

  #ランダムな行動を選択
  if epsilon>np.random.rand():
    action=env.action_space.sample()
  #行動価値関数で行動を選択
  else:
    action=np.argmax(main_qn.model.predict(state)[0])

    #行動に応じて状態と報酬を得る
    next_state, _, done, _ =env.step(action)
    next_state=np.reshape(next_state,[1,state_size])

    #エピソード完了時
    if done:
      #報酬の指定
      if step>=190:
        success_count+=1
        reward=1
      else:
        success_count=0
        reward=0

      #次の状態に状態なしを代入
      next_state=np.zeros(state.shape)

      #経験の追加
      if step>WARMUP:
        memory.add((state,action,reward,next_state))

      #状態に次の状態を代入
      state=next_state

    #行動価値関数の更新
    if len(memory)>=BATCH_SIZE:
      #NNの入力と出力の準備
      inputs=np.zeros((BATCH_SIZE,4)) #入力(状態)
      targets=np.zeros((BATCH_SIZE,2)) #出力(行動ごとの価値)

      #バッチサイズ分の経験をランダムに取得
      minibatch=memory.sample(BATCH_SIZE)

      #NNの入力と出力の生成
      for i, (state_b,action_b,reward_b,next_state_b) in enumerate(minibatch):
        
        #入力に状態を指定
        inputs[i]=state_b

        #とった行動の価値を計算
        if not(next_state_b==np.zeros(state_b.shape)).all(axis=1):
          target=reward_b+GAMMA*np.amax(target_qn.model.predict(next_state_b)[0])
        else:
          target=reward_b

        #出力に行動ごとの価値を指定
        targets[i]=main.qn.predict(state_b)
        targets[i][action_b]=target #とった行動の価値

      #エピソード完了時
      if done:
        break
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/logger.py:30: UserWarning: WARN: You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
#ディスプレイ設定のインストール
# !apt-get -qq -y install xvfb freelut3-dev ffmpeg> /dev/null
# !pip install pyglet
# !pip install pyopengl
# !pip install pyvirtualdisplay

#ディスプレイ設定の適用
from pyvirtualdisplay import Display
import os
disp=Display(visible=0,size=(1024,768))
disp.start()
os.environ['DISPLAY']=':' +str(disp.display)+ '.' +str(disp.screen)
# Out:
# E: Unable to locate package freelut3-dev
# Requirement already satisfied: pyglet in /usr/local/lib/python3.6/dist-packages (1.5.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet) (0.16.0)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.6/dist-packages (3.1.5)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.6/dist-packages (1.3.2)
# Requirement already satisfied: EasyProcess in /usr/local/lib/python3.6/dist-packages (from pyvirtualdisplay) (0.3)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/easyprocess/__init__.py in start(self)
#     168             self.popen = subprocess.Popen(
# --> 169                 cmd, stdout=stdout, stderr=stderr, cwd=self.cwd, env=self.env,
#     170             )
#
# /usr/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
#     730         except:
#
# /usr/lib/python3.6/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1363                             err_msg += ': ' + repr(err_filename)
# -> 1364                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1365                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Xvfb': 'Xvfb'
#
# During handling of the above exception, another exception occurred:
#
# EasyProcessError                          Traceback (most recent call last)
# <ipython-input-37-1771be566841> in <module>()
#       8 from pyvirtualdisplay import Display
#       9 import os
# ---> 10 disp=Display(visible=0,size=(1024,768))
#      11 disp.start()
#      12 os.environ['DISPLAY']=':' +str(disp.display)+ '.' +str(disp.screen)
#
# /usr/local/lib/python3.6/dist-packages/pyvirtualdisplay/display.py in __init__(self, backend, visible, size, color_depth, bgcolor, use_xauth, randomizer, retries, extra_args, **kwargs)
#      56             # check_startup=check_startup,
#      57             extra_args=extra_args,
# ---> 58             **kwargs
#      59         )
#      60
#
# /usr/local/lib/python3.6/dist-packages/pyvirtualdisplay/xvfb.py in __init__(self, size, color_depth, bgcolor, use_xauth, fbdir, dpi, randomizer, retries, extra_args)
#      52             randomizer=randomizer,
#      53             retries=retries,
# ---> 54             extra_args=extra_args,
#      55         )
#      56
#
# /usr/local/lib/python3.6/dist-packages/pyvirtualdisplay/abstractdisplay.py in __init__(self, program, use_xauth, randomizer, retries, extra_args)
#      85         self.is_started = False
#      86
# ---> 87         helptext = get_helptext(program)
#      88         self._has_displayfd = "-displayfd" in helptext
#      89         if not self._has_displayfd:
#
# /usr/local/lib/python3.6/dist-packages/pyvirtualdisplay/util.py in get_helptext(program)
#       8     p.enable_stdout_log = False
#       9     p.enable_stderr_log = False
# ---> 10     p.call()
#      11     helptext = p.stderr
#      12     return helptext
#
# /usr/local/lib/python3.6/dist-packages/easyprocess/__init__.py in call(self, timeout)
#     139
#     140         """
# --> 141         self.start().wait(timeout=timeout)
#     142         if self.is_alive():
#     143             self.stop()
#
# /usr/local/lib/python3.6/dist-packages/easyprocess/__init__.py in start(self)
#     172             log.debug("OSError exception: %s", oserror)
#     173             self.oserror = oserror
# --> 174             raise EasyProcessError(self, "start error")
#     175         self.is_started = True
#     176         log.debug("process was started (pid=%s)", self.pid)
#
# EasyProcessError: start error <EasyProcess cmd_param=['Xvfb', '-help'] cmd=['Xvfb', '-help'] oserror=[Errno 2] No such file or directory: 'Xvfb': 'Xvfb' return_code=None stdout="None" stderr="None" timeout_happened=False>

# %%
#評価
frames=[]  #アニメーションフレーム

#環境のリセット
state=env.reset()
state=np.reshape(state,[1,state_size])

#1エピソードのループ
step=0 #ステップ数
for step in range(1,MAX_STEPS+1):
  step+=1

  #アニメーションフレームの追加
  frames.append(env.render(mode='rgb_array'))

  #最適行動を選択
  action=np.argmax(main_qn.model.predict(state)[0])

  #行動に応じて状態と報酬を得る
  next_state,reward,done, _ =env.step(action)
  next_state=np.reshape(next_state,[1,state_size])

  #エピソード完了
  if done:
    #次の状態に状態なしを代入
    next_state=np.zeros(state.shape)

    break
  else:
    state=next_state
print('ステップ数:{}'.format(step))

# %%
#JSAnimationのインストール
# !pip install JSAnimation

#パッケージのインポート
import matplotlib.pyplot as plt
from matplotlib import animation
from JSAnimation.IPython_display import display_animation
from IPython.display import display

#アニメーション再生の定義
def display_frame_as_gif(frame):
  plt.figure(figsize=(frames[0].shape[1]/72.0,frames[0].shaple[0]/72.0),dpi=72)
  patch=plt.imshow(frames[0])
  plt.axis('off')

  #アニメーションの定期処理
  def animate(i):
    patch.set_data(frames[i])

    anim=animation.FuncAnimation(plt.gcf(),animate,frames=len(frames),interval=50)
    display(display_animation(anim,default_node='loop'))

display_frames_as_gif(frames)
