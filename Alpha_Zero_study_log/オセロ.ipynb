# %%
import numpy as np

#オセロ作成
WHITE=1
BLACK=-1
BLANK=0
BOARD_SIZE=8

#マスの作成
class Board(object):
  def init(self):
    #2次元リストを作成
    self.cells=np.zeros((BOARD_SIZE,BOARD_SIZE))  #マスを初期化
    self.cell=self.cell.astype(int) #マスの配列の中身を計算できるようにする
    self.cell[3][3]=self.cell[4][4]=1  #このマスに白をおく
    self.cell[3][4]=self.cell[4][3]=-1  #このマスに黒をおく
    self.current=BLACK  #最初は黒からスタート
    self.pass_count=0  #パスした回数
    self.turn=1  #ターンした回数
    
  def turnchange(self):
    self.current*=-1  #黒と白を入れ替える  -1=-1*-1で1となり,1=1*-1で-1となる
  
  def stonenumber(self):
    return self.stones

  def rangecheck(self,x,y):  #盤内かどうか
    if x ==None:  x=-1
    if y ==None: y=-1
    if x<0 or BOARD_SIZE<=x or y <0 or BOARD_SIZE<=y:
      return False
    return True
  
  def check_can_reverse(self,x,y):  #置けるかどうか
    if not self.rangecheck(x,y):
      return False
    elif not self.cell[x][y]==BLANK:
      return False
    elif not self.can_reverse_stone(x,y):
      return False
    else: return True

  def can_reverse_one(self,x,y):
    for dx in range(-1,2):
      






if_name_=='__main__':
  board=Board()
  board.display()
  board.put_stone(3,2)
  board.display()
  board.put_stone(2,2)
  board.display()
# Out:
# [[None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None], [None, None, None, None, None, None, None, None]]
