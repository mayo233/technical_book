# %%
import numpy as np

#最小2乗法の処理を行う関数
def multiply(A,b):
  x=(np.linalg.pinv((A.T)@(A)))@(A.T@b) #最適解x=(A^T*A)^-1*A^T*bを表現
  return x  #xを返す

A=np.array([[1,3,3],[-2,-4,-2],[1,1,-1]]) 
b=np.array([-11,14,-2])
print(multiply(A,b))
# Out:
# [-1.1547619  -2.28571429 -1.10714286]
